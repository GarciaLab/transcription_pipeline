# %%
import pims

def import_dataset(name_folder):
    """
    Imports and cleans up the data files in the name directory (removes
    incompletely scanned frames) and exports the resulting file as a
    TIFF file along with the relevant metadata. All files are exported
    to a "preprocessed_data" folder in the name folder (created if it
    does not already exist).
    
    :param str name_folder: Path to name folder containing data files.
    :return: 
    """

# %%
import pims
import glob

# %%
name_folder = 'test_data/2023-04-07/p2pdp_zld-sites-ctrl_fwd_1'
dataset_name = name_folder.split('/')[-1]
file_path = ''.join([name_folder, '/', dataset_name, '*'])
file_list = glob.glob(file_path)

# %%
data = []

for file in file_list:
    data.append(pims.Bioformats(file))
# Out:
# /home/yovan/mambaforge/envs/transcription_pipeline/lib/python3.8/site-packages/pims/bioformats.py:50: UserWarning: loci_tools.jar not found, downloading
#   warn('loci_tools.jar not found, downloading')
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 data = []
#       3 for file in file_list:
# ----> 4     data.append(pims.Bioformats(file))
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/site-packages/pims/bioformats.py:335, in BioformatsReader.__init__(self, filename, meta, java_memory, read_mode, series)
#     332 if not jpype.isJVMStarted():
#     333     from distutils.version import LooseVersion
# --> 335     loci_path = _find_jar()
#     336     # If we can turn off string auto-conversion, do so,
#     337     # since this is the recommended practice.
#     338     if LooseVersion(jpype.__version__) >= LooseVersion('0.7.0'):
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/site-packages/pims/bioformats.py:51, in _find_jar()
#      48         return os.path.join(loc, 'loci_tools.jar')
#      50 warn('loci_tools.jar not found, downloading')
# ---> 51 return download_jar()
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/site-packages/pims/bioformats.py:78, in download_jar(version)
#      74 url = ('http://downloads.openmicroscopy.org/bio-formats/' + version +
#      75        '/artifacts/loci_tools.jar')
#      77 path = os.path.join(loc, 'loci_tools.jar')
# ---> 78 loci_tools = urlopen(url).read()
#      79 sha1_checksum = urlopen(url + '.sha1').read().split(b' ')[0].decode()
#      81 downloaded = hashlib.sha1(loci_tools).hexdigest()
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561     http_err = 0
#     562 args = (dict, proto, meth_name) + args
# --> 563 result = self._call_chain(*args)
#     564 if result:
#     565     return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:755, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     752 fp.read()
#     753 fp.close()
# --> 755 return self.parent.open(new, timeout=req.timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561     http_err = 0
#     562 args = (dict, proto, meth_name) + args
# --> 563 result = self._call_chain(*args)
#     564 if result:
#     565     return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:755, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     752 fp.read()
#     753 fp.close()
# --> 755 return self.parent.open(new, timeout=req.timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:569, in OpenerDirector.error(self, proto, *args)
#     567 if http_err:
#     568     args = (dict, 'default', 'http_error_default') + orig_args
# --> 569     return self._call_chain(*args)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:649, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     648 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
pims.bioformats.download_jar(version='6.13')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pims.bioformats.download_jar(version='6.13')
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/site-packages/pims/bioformats.py:78, in download_jar(version)
#      74 url = ('http://downloads.openmicroscopy.org/bio-formats/' + version +
#      75        '/artifacts/loci_tools.jar')
#      77 path = os.path.join(loc, 'loci_tools.jar')
# ---> 78 loci_tools = urlopen(url).read()
#      79 sha1_checksum = urlopen(url + '.sha1').read().split(b' ')[0].decode()
#      81 downloaded = hashlib.sha1(loci_tools).hexdigest()
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561     http_err = 0
#     562 args = (dict, proto, meth_name) + args
# --> 563 result = self._call_chain(*args)
#     564 if result:
#     565     return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:755, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     752 fp.read()
#     753 fp.close()
# --> 755 return self.parent.open(new, timeout=req.timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561     http_err = 0
#     562 args = (dict, proto, meth_name) + args
# --> 563 result = self._call_chain(*args)
#     564 if result:
#     565     return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:755, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     752 fp.read()
#     753 fp.close()
# --> 755 return self.parent.open(new, timeout=req.timeout)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:569, in OpenerDirector.error(self, proto, *args)
#     567 if http_err:
#     568     args = (dict, 'default', 'http_error_default') + orig_args
# --> 569     return self._call_chain(*args)
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/mambaforge/envs/transcription_pipeline/lib/python3.8/urllib/request.py:649, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     648 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
